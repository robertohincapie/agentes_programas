# %%
from buscador_programas import research_program_tool, build_web_research_agent, run_for_index
programas=[{
            "Programa": "Ingenieria Materiales",
            "Institución": "Universidad Antioquia",
            "Municipio": "Medellin",
            "URL": "Www.Udea.Edu.Co",
            "URL_programa": ""
        },
        {
            "Programa": "Ingenieria Materiales",
            "Institución": "Universidad Valle",
            "Municipio": "Santiago Cali",
            "URL": "Www.Univalle.Edu.Co",
            "URL_programa": ""
        },
        {
            "Programa": "Ingenieria Materiales",
            "Institución": "Universidad San Buenaventura",
            "Municipio": "Santiago Cali",
            "URL": "Www.Usbcali.Edu.Co",
            "URL_programa": ""
        }]
print(run_for_index(programas, 1))
# Out:
# c:\Users\000010478\Downloads\agentes_programas\notebooks\buscador_programas.py:89: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tavily_tool = TavilySearchResults(
# ---------------------------------------------------------------------------
# GraphRecursionError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from buscador_programas import research_program_tool, build_web_research_agent, run_for_index
#       2 programas=[{
#       3             "Programa": "Ingenieria Materiales",
#       4             "Institución": "Universidad Antioquia",
#    (...)     21             "URL_programa": ""
#      22         }]
#      23 print(run_for_index(programas, 1))
#
# ...
